# %%
import pandas

# %%
cards = pandas.read_pickle("data/cards.p")

# %%
data_frame_cards = pandas.DataFrame(cards)

# %%
data_frame_cards.head()
# Out:
#                                            abilities           artist  \
# 0  [{'name': 'Damage Swap', 'text': 'As often as ...     Ken Sugimori
# 1  [{'name': 'Rain Dance', 'text': 'As often as y...     Ken Sugimori
# 2                                               None     Ken Sugimori
# 3  [{'name': 'Energy Burn', 'text': 'As often as ...  Mitsuhiro Arita
# 4                                               None     Ken Sugimori
#
#   ancientTrait                                            attacks  \
# 0         None  [{'name': 'Confuse Ray', 'cost': ['Psychic', '...
# 1         None  [{'name': 'Hydro Pump', 'cost': ['Water', 'Wat...
# 2         None  [{'name': 'Scrunch', 'cost': ['Colorless', 'Co...
# 3         None  [{'name': 'Fire Spin', 'cost': ['Fire', 'Fire'...
# 4         None  [{'name': 'Sing', 'cost': ['Colorless'], 'conv...
#
#                                           cardmarket  convertedRetreatCost  \
# 0  {'url': 'https://prices.pokemontcg.io/cardmark...                   3.0
# 1  {'url': 'https://prices.pokemontcg.io/cardmark...                   3.0
# 2  {'url': 'https://prices.pokemontcg.io/cardmark...                   1.0
# 3  {'url': 'https://prices.pokemontcg.io/cardmark...                   3.0
# 4  {'url': 'https://prices.pokemontcg.io/cardmark...                   1.0
#
#   evolvesFrom                                         flavorText   hp  \
# 0     Kadabra  Its brain can outperform a supercomputer. Its ...   80
# 1   Wartortle  A brutal Pokémon with pressurized water jets o...  100
# 2        None  A rare and elusive Pokémon that is said to bri...  120
# 3  Charmeleon  Spits fire that is hot enough to melt boulders...  120
# 4        None  Its magical and cute appeal has many admirers....   40
#
#         id  ...     rarity                             resistances  \
# 0  base1-1  ...  Rare Holo                                    None
# 1  base1-2  ...  Rare Holo                                    None
# 2  base1-3  ...  Rare Holo   [{'type': 'Psychic', 'value': '-30'}]
# 3  base1-4  ...  Rare Holo  [{'type': 'Fighting', 'value': '-30'}]
# 4  base1-5  ...  Rare Holo   [{'type': 'Psychic', 'value': '-30'}]
#
#                          retreatCost rules  \
# 0  [Colorless, Colorless, Colorless]  None
# 1  [Colorless, Colorless, Colorless]  None
# 2                        [Colorless]  None
# 3  [Colorless, Colorless, Colorless]  None
# 4                        [Colorless]  None
#
#                                                  set   subtypes supertype  \
# 0  {'id': 'base1', 'images': {'symbol': 'https://...  [Stage 2]   Pokémon
# 1  {'id': 'base1', 'images': {'symbol': 'https://...  [Stage 2]   Pokémon
# 2  {'id': 'base1', 'images': {'symbol': 'https://...    [Basic]   Pokémon
# 3  {'id': 'base1', 'images': {'symbol': 'https://...  [Stage 2]   Pokémon
# 4  {'id': 'base1', 'images': {'symbol': 'https://...    [Basic]   Pokémon
#
#                                            tcgplayer        types  \
# 0  {'url': 'https://prices.pokemontcg.io/tcgplaye...    [Psychic]
# 1  {'url': 'https://prices.pokemontcg.io/tcgplaye...      [Water]
# 2  {'url': 'https://prices.pokemontcg.io/tcgplaye...  [Colorless]
# 3  {'url': 'https://prices.pokemontcg.io/tcgplaye...       [Fire]
# 4  {'url': 'https://prices.pokemontcg.io/tcgplaye...  [Colorless]
#
#                                weaknesses
# 0    [{'type': 'Psychic', 'value': '×2'}]
# 1  [{'type': 'Lightning', 'value': '×2'}]
# 2   [{'type': 'Fighting', 'value': '×2'}]
# 3      [{'type': 'Water', 'value': '×2'}]
# 4   [{'type': 'Fighting', 'value': '×2'}]
#
# [5 rows x 26 columns]

# %%
data_frame_cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15845 entries, 0 to 15844
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   abilities               3181 non-null   object
#  1   artist                  15557 non-null  object
#  2   ancientTrait            57 non-null     object
#  3   attacks                 13365 non-null  object
#  4   cardmarket              15628 non-null  object
#  5   convertedRetreatCost    12588 non-null  float64
#  6   evolvesFrom             5669 non-null   object
#  7   flavorText              8730 non-null   object
#  8   hp                      13392 non-null  object
#  9   id                      15845 non-null  object
#  10  images                  15845 non-null  object
#  11  legalities              15845 non-null  object
#  12  regulationMark          3521 non-null   object
#  13  name                    15845 non-null  object
#  14  nationalPokedexNumbers  13351 non-null  object
#  15  number                  15845 non-null  object
#  16  rarity                  15550 non-null  object
#  17  resistances             4050 non-null   object
#  18  retreatCost             12588 non-null  object
#  19  rules                   4804 non-null   object
#  20  set                     15845 non-null  object
#  21  subtypes                15643 non-null  object
#  22  supertype               15845 non-null  object
#  23  tcgplayer               15623 non-null  object
#  24  types                   13357 non-null  object
#  25  weaknesses              12959 non-null  object
# dtypes: float64(1), object(25)
# memory usage: 3.1+ MB

# %%
data_frame_cards["rarity"].value_counts()
# Out:
# Common                         3914
# Uncommon                       3892
# Rare                           2212
# Rare Holo                      1656
# Promo                          1030
# Rare Ultra                      782
# Rare Rainbow                    324
# Rare Holo EX                    320
# Rare Secret                     313
# Rare Holo V                     272
# Rare Holo GX                    165
# Rare Shiny                      149
# Rare Holo VMAX                   90
# Rare Holo LV.X                   56
# Trainer Gallery Rare Holo        45
# Rare Shiny GX                    35
# Rare Holo VSTAR                  33
# Trainer Gallery Rare Holo V      33
# Rare BREAK                       27
# Rare Prism Star                  27
# Rare Prime                       26
# Rare Holo Star                   25
# Classic Collection               25
# LEGEND                           18
# Rare Shining                     16
# Trainer Gallery Rare Ultra       16
# Radiant Rare                     15
# Rare ACE                         13
# Amazing Rare                      9
# Trainer Gallery Rare Secret       6
# V                                 4
# VM                                2
# Name: rarity, dtype: int64

# %%
data_frame_cards["types"].value_counts()
# Out:
# [Water]                  1920
# [Grass]                  1852
# [Psychic]                1792
# [Colorless]              1731
# [Fighting]               1426
# [Fire]                   1186
# [Lightning]              1157
# [Darkness]                842
# [Metal]                   698
# [Dragon]                  416
# [Fairy]                   234
# [Grass, Darkness]          10
# [Lightning, Metal]          9
# [Fighting, Darkness]        9
# [Darkness, Metal]           7
# [Water, Metal]              7
# [Water, Darkness]           7
# [Fire, Metal]               6
# [Psychic, Metal]            5
# [Fire, Darkness]            5
# [Lightning, Darkness]       5
# [Fighting, Metal]           4
# [Fire, Water]               4
# [Psychic, Darkness]         3
# [Grass, Metal]              3
# [Darkness, Psychic]         2
# [Metal, Fighting]           2
# [Water, Fire]               2
# [Colorless, Psychic]        2
# [Water, Fighting]           2
# [Lightning, Water]          2
# [Fire, Lightning]           2
# [Fairy, Psychic]            2
# [Fire, Grass]               1
# [Lightning, Grass]          1
# [Fairy, Water]              1
# Name: types, dtype: int64

# %%
pandas.set_option('display.max_rows', 500)
data_frame_cards["id"].head(500)
# Out:
# 0        base1-1
# 1        base1-2
# 2        base1-3
# 3        base1-4
# 4        base1-5
# 5        base1-6
# 6        base1-7
# 7        base1-8
# 8        base1-9
# 9       base1-10
# 10      base1-11
# 11      base1-12
# 12      base1-13
# 13      base1-14
# 14      base1-15
# 15      base1-16
# 16      base1-17
# 17      base1-18
# 18      base1-19
# 19      base1-20
# 20      base1-21
# 21      base1-22
# 22      base1-23
# 23      base1-24
# 24      base1-25
# 25      base1-26
# 26      base1-27
# 27      base1-28
# 28      base1-29
# 29      base1-30
# 30      base1-31
# 31      base1-32
# 32      base1-33
# 33      base1-34
# 34      base1-35
# 35      base1-36
# 36      base1-37
# 37      base1-38
# 38      base1-39
# 39      base1-40
# 40      base1-41
# 41      base1-42
# 42      base1-43
# 43      base1-44
# 44      base1-45
# 45      base1-46
# 46      base1-47
# 47      base1-48
# 48      base1-49
# 49      base1-50
# 50      base1-51
# 51      base1-52
# 52      base1-53
# 53      base1-54
# 54      base1-55
# 55      base1-56
# 56      base1-57
# 57      base1-58
# 58      base1-59
# 59      base1-60
# 60      base1-61
# 61      base1-62
# 62      base1-63
# 63      base1-64
# 64      base1-65
# 65      base1-66
# 66      base1-67
# 67      base1-68
# 68      base1-69
# 69      base1-70
# 70      base1-71
# 71      base1-72
# 72      base1-73
# 73      base1-74
# 74      base1-75
# 75      base1-76
# 76      base1-77
# 77      base1-78
# 78      base1-79
# 79      base1-80
# 80      base1-81
# 81      base1-82
# 82      base1-83
# 83      base1-84
# 84      base1-85
# 85      base1-86
# 86      base1-87
# 87      base1-88
# 88      base1-89
# 89      base1-90
# 90      base1-91
# 91      base1-92
# 92      base1-93
# 93      base1-94
# 94      base1-95
# 95      base1-96
# 96      base1-97
# 97      base1-98
# 98      base1-99
# 99     base1-100
# 100    base1-101
# 101    base1-102
# 102      base2-1
# 103      base2-2
# 104      base2-3
# 105      base2-4
# 106      base2-5
# 107      base2-6
# 108      base2-7
# 109      base2-8
# 110      base2-9
# 111     base2-10
# 112     base2-11
# 113     base2-12
# 114     base2-13
# 115     base2-14
# 116     base2-15
# 117     base2-16
# 118     base2-17
# 119     base2-18
# 120     base2-19
# 121     base2-20
# 122     base2-21
# 123     base2-22
# 124     base2-23
# 125     base2-24
# 126     base2-25
# 127     base2-26
# 128     base2-27
# 129     base2-28
# 130     base2-29
# 131     base2-30
# 132     base2-31
# 133     base2-32
# 134     base2-33
# 135     base2-34
# 136     base2-35
# 137     base2-36
# 138     base2-37
# 139     base2-38
# 140     base2-39
# 141     base2-40
# 142     base2-41
# 143     base2-42
# 144     base2-43
# 145     base2-44
# 146     base2-45
# 147     base2-46
# 148     base2-47
# 149     base2-48
# 150     base2-49
# 151     base2-50
# 152     base2-51
# 153     base2-52
# 154     base2-53
# 155     base2-54
# 156     base2-55
# 157     base2-56
# 158     base2-57
# 159     base2-58
# 160     base2-59
# 161     base2-60
# 162     base2-61
# 163     base2-62
# 164     base2-63
# 165     base2-64
# 166      basep-1
# 167      basep-2
# 168      basep-3
# 169      basep-4
# 170      basep-5
# 171      basep-6
# 172      basep-7
# 173      basep-8
# 174      basep-9
# 175     basep-10
# 176     basep-11
# 177     basep-12
# 178     basep-13
# 179     basep-14
# 180     basep-15
# 181     basep-16
# 182     basep-17
# 183     basep-18
# 184     basep-19
# 185     basep-20
# 186     basep-21
# 187     basep-22
# 188     basep-23
# 189     basep-24
# 190     basep-25
# 191     basep-26
# 192     basep-27
# 193     basep-28
# 194     basep-29
# 195     basep-30
# 196     basep-31
# 197     basep-32
# 198     basep-33
# 199     basep-34
# 200     basep-35
# 201     basep-36
# 202     basep-37
# 203     basep-38
# 204     basep-39
# 205     basep-40
# 206     basep-41
# 207     basep-42
# 208     basep-43
# 209     basep-44
# 210     basep-45
# 211     basep-46
# 212     basep-47
# 213     basep-48
# 214     basep-49
# 215     basep-50
# 216     basep-51
# 217     basep-52
# 218     basep-53
# 219      base3-1
# 220      base3-2
# 221      base3-3
# 222      base3-4
# 223      base3-5
# 224      base3-6
# 225      base3-7
# 226      base3-8
# 227      base3-9
# 228     base3-10
# 229     base3-11
# 230     base3-12
# 231     base3-13
# 232     base3-14
# 233     base3-15
# 234     base3-16
# 235     base3-17
# 236     base3-18
# 237     base3-19
# 238     base3-20
# 239     base3-21
# 240     base3-22
# 241     base3-23
# 242     base3-24
# 243     base3-25
# 244     base3-26
# 245     base3-27
# 246     base3-28
# 247     base3-29
# 248     base3-30
# 249     base3-31
# 250     base3-32
# 251     base3-33
# 252     base3-34
# 253     base3-35
# 254     base3-36
# 255     base3-37
# 256     base3-38
# 257     base3-39
# 258     base3-40
# 259     base3-41
# 260     base3-42
# 261     base3-43
# 262     base3-44
# 263     base3-45
# 264     base3-46
# 265     base3-47
# 266     base3-48
# 267     base3-49
# 268     base3-50
# 269     base3-51
# 270     base3-52
# 271     base3-53
# 272     base3-54
# 273     base3-55
# 274     base3-56
# 275     base3-57
# 276     base3-58
# 277     base3-59
# 278     base3-60
# 279     base3-61
# 280     base3-62
# 281      base4-1
# 282      base4-2
# 283      base4-3
# 284      base4-4
# 285      base4-5
# 286      base4-6
# 287      base4-7
# 288      base4-8
# 289      base4-9
# 290     base4-10
# 291     base4-11
# 292     base4-12
# 293     base4-13
# 294     base4-14
# 295     base4-15
# 296     base4-16
# 297     base4-17
# 298     base4-18
# 299     base4-19
# 300     base4-20
# 301     base4-21
# 302     base4-22
# 303     base4-23
# 304     base4-24
# 305     base4-25
# 306     base4-26
# 307     base4-27
# 308     base4-28
# 309     base4-29
# 310     base4-30
# 311     base4-31
# 312     base4-32
# 313     base4-33
# 314     base4-34
# 315     base4-35
# 316     base4-36
# 317     base4-37
# 318     base4-38
# 319     base4-39
# 320     base4-40
# 321     base4-41
# 322     base4-42
# 323     base4-43
# 324     base4-44
# 325     base4-45
# 326     base4-46
# 327     base4-47
# 328     base4-48
# 329     base4-49
# 330     base4-50
# 331     base4-51
# 332     base4-52
# 333     base4-53
# 334     base4-54
# 335     base4-55
# 336     base4-56
# 337     base4-57
# 338     base4-58
# 339     base4-59
# 340     base4-60
# 341     base4-61
# 342     base4-62
# 343     base4-63
# 344     base4-64
# 345     base4-65
# 346     base4-66
# 347     base4-67
# 348     base4-68
# 349     base4-69
# 350     base4-70
# 351     base4-71
# 352     base4-72
# 353     base4-73
# 354     base4-74
# 355     base4-75
# 356     base4-76
# 357     base4-77
# 358     base4-78
# 359     base4-79
# 360     base4-80
# 361     base4-81
# 362     base4-82
# 363     base4-83
# 364     base4-84
# 365     base4-85
# 366     base4-86
# 367     base4-87
# 368     base4-88
# 369     base4-89
# 370     base4-90
# 371     base4-91
# 372     base4-92
# 373     base4-93
# 374     base4-94
# 375     base4-95
# 376     base4-96
# 377     base4-97
# 378     base4-98
# 379     base4-99
# 380    base4-100
# 381    base4-101
# 382    base4-102
# 383    base4-103
# 384    base4-104
# 385    base4-105
# 386    base4-106
# 387    base4-107
# 388    base4-108
# 389    base4-109
# 390    base4-110
# 391    base4-111
# 392    base4-112
# 393    base4-113
# 394    base4-114
# 395    base4-115
# 396    base4-116
# 397    base4-117
# 398    base4-118
# 399    base4-119
# 400    base4-120
# 401    base4-121
# 402    base4-122
# 403    base4-123
# 404    base4-124
# 405    base4-125
# 406    base4-126
# 407    base4-127
# 408    base4-128
# 409    base4-129
# 410    base4-130
# 411      base5-1
# 412      base5-2
# 413      base5-3
# 414      base5-4
# 415      base5-5
# 416      base5-6
# 417      base5-7
# 418      base5-8
# 419      base5-9
# 420     base5-10
# 421     base5-11
# 422     base5-12
# 423     base5-13
# 424     base5-14
# 425     base5-15
# 426     base5-16
# 427     base5-17
# 428     base5-18
# 429     base5-19
# 430     base5-20
# 431     base5-21
# 432     base5-22
# 433     base5-23
# 434     base5-24
# 435     base5-25
# 436     base5-26
# 437     base5-27
# 438     base5-28
# 439     base5-29
# 440     base5-30
# 441     base5-31
# 442     base5-32
# 443     base5-33
# 444     base5-34
# 445     base5-35
# 446     base5-36
# 447     base5-37
# 448     base5-38
# 449     base5-39
# 450     base5-40
# 451     base5-41
# 452     base5-42
# 453     base5-43
# 454     base5-44
# 455     base5-45
# 456     base5-46
# 457     base5-47
# 458     base5-48
# 459     base5-49
# 460     base5-50
# 461     base5-51
# 462     base5-52
# 463     base5-53
# 464     base5-54
# 465     base5-55
# 466     base5-56
# 467     base5-57
# 468     base5-58
# 469     base5-59
# 470     base5-60
# 471     base5-61
# 472     base5-62
# 473     base5-63
# 474     base5-64
# 475     base5-65
# 476     base5-66
# 477     base5-67
# 478     base5-68
# 479     base5-69
# 480     base5-70
# 481     base5-71
# 482     base5-72
# 483     base5-73
# 484     base5-74
# 485     base5-75
# 486     base5-76
# 487     base5-77
# 488     base5-78
# 489     base5-79
# 490     base5-80
# 491     base5-81
# 492     base5-82
# 493     base5-83
# 494       gym1-1
# 495       gym1-2
# 496       gym1-3
# 497       gym1-4
# 498       gym1-5
# 499       gym1-6
# Name: id, dtype: object

# %%
data_frame_cards[data_frame_cards["id"].str.contains("_")]
# Out:
#                                                abilities             artist  \
# 14118                                               None    Kagemaru Himeno
# 14119  [{'name': 'Rain Dance', 'text': 'As often as y...       Ken Sugimori
# 14120  [{'name': 'Healing Breath', 'text': 'Once duri...           Shizurow
# 14121  [{'name': 'Energy Trans', 'text': 'As often as...    Mitsuhiro Arita
# 14122  [{'name': 'Energy Burn', 'text': 'As often as ...    Mitsuhiro Arita
# 14123                                               None       Ken Sugimori
# 14124  [{'name': 'Cosmic Power', 'text': 'Once during...      Midori Harada
# 14125                                               None       Ken Sugimori
# 14126  [{'name': 'Versatile', 'text': 'Mew ex can use...           Ryo Ueda
# 14127                                               None  Shin-ichi Yoshida
# 14128  [{'name': 'Final Beam', 'text': 'When Dark Gya...    Kagemaru Himeno
# 14129                                               None    Kagemaru Himeno
# 14130                                               None       Ken Sugimori
# 14131  [{'name': 'Power Saver', 'text': 'As long as t...       Kazuo Yazawa
# 14132                                               None       Ken Sugimori
# 14133  [{'name': 'Imprison', 'text': 'Once during you...     Masahiko Ishii
# 14134  [{'name': 'Dark Ray', 'text': 'Once during you...    Masakazu Fukuda
# 14135  [{'name': 'Bright Look', 'text': 'Once during ...    Mitsuhiro Arita
# 14136                                               None      5ban Graphics
# 14137                                               None           Shizurow
# 14138                                               None      5ban Graphics
# 14139                                               None      5ban Graphics
# 14140  [{'name': 'Wonder Tag', 'text': 'When you play...      5ban Graphics
# 14141  [{'name': 'Exoskeleton', 'text': 'Any damage d...     Kent Kanetsuna
# 14142                                               None      5ban Graphics
#
#                                             ancientTrait  \
# 14118                                               None
# 14119                                               None
# 14120                                               None
# 14121                                               None
# 14122                                               None
# 14123                                               None
# 14124                                               None
# 14125                                               None
# 14126                                               None
# 14127                                               None
# 14128                                               None
# 14129                                               None
# 14130                                               None
# 14131                                               None
# 14132                                               None
# 14133                                               None
# 14134                                               None
# 14135                                               None
# 14136                                               None
# 14137                                               None
# 14138                                               None
# 14139  {'name': 'Δ Evolution', 'text': 'You may play ...
# 14140                                               None
# 14141                                               None
# 14142                                               None
#
#                                                  attacks cardmarket  \
# 14118  [{'name': 'Eeeeeeek', 'cost': ['Colorless'], '...       None
# 14119  [{'name': 'Hydro Pump', 'cost': ['Water', 'Wat...       None
# 14120  [{'name': 'Dragon Rush', 'cost': ['Colorless',...       None
# 14121  [{'name': 'Solarbeam', 'cost': ['Grass', 'Gras...       None
# 14122  [{'name': 'Fire Spin', 'cost': ['Fire', 'Fire'...       None
# 14123                                               None       None
# 14124  [{'name': 'Spinning Attack', 'cost': ['Fightin...       None
# 14125                                               None       None
# 14126  [{'name': 'Power Move', 'cost': ['Psychic', 'C...       None
# 14127  [{'name': 'Plasma', 'cost': ['Lightning'], 'co...       None
# 14128  [{'name': 'Ice Beam', 'cost': ['Water', 'Water...       None
# 14129  [{'name': 'Birthday Surprise', 'cost': ['Light...       None
# 14130  [{'name': 'Gold Scale', 'cost': ['Water'], 'co...       None
# 14131  [{'name': 'Linear Attack', 'cost': ['Fighting'...       None
# 14132                                               None       None
# 14133  [{'name': 'Flame Ball', 'cost': ['Fire', 'Colo...       None
# 14134  [{'name': 'Feint Attack', 'cost': ['Darkness',...       None
# 14135  [{'name': 'Flash Impact', 'cost': ['Lightning'...       None
# 14136  [{'name': 'Break Through', 'cost': ['Fairy', '...       None
# 14137  [{'name': 'X Ball', 'cost': ['Colorless', 'Col...       None
# 14138  [{'name': 'Outrage', 'cost': ['Colorless', 'Co...       None
# 14139  [{'name': 'Emerald Break', 'cost': ['Colorless...       None
# 14140  [{'name': 'Energy Drive', 'cost': ['Colorless'...       None
# 14141  [{'name': 'Earthquake', 'cost': ['Fighting'], ...       None
# 14142  [{'name': 'Outrage', 'cost': ['Colorless', 'Co...       None
#
#        convertedRetreatCost  evolvesFrom  \
# 14118                   NaN         None
# 14119                   3.0    Wartortle
# 14120                   NaN   Garchomp C
# 14121                   2.0      Ivysaur
# 14122                   3.0   Charmeleon
# 14123                   NaN         None
# 14124                   2.0       Baltoy
# 14125                   NaN         None
# 14126                   1.0         None
# 14127                   2.0         None
# 14128                   2.0     Magikarp
# 14129                   1.0         None
# 14130                   1.0         None
# 14131                   3.0         None
# 14132                   NaN         None
# 14133                   2.0       Kirlia
# 14134                   1.0         None
# 14135                   NaN    Luxray GL
# 14136                   2.0         None
# 14137                   2.0         None
# 14138                   2.0         None
# 14139                   1.0  Rayquaza-EX
# 14140                   1.0         None
# 14141                   4.0       Phanpy
# 14142                   2.0         None
#
#                                               flavorText    hp            id  \
# 14118                                               None    30   cel25c-20_A
# 14119  A brutal Pokémon with pressurized water jets o...   100    cel25c-2_A
# 14120                                               None   110  cel25c-145_A
# 14121  This plant blooms when it is absorbing solar e...   100  cel25c-15_A1
# 14122  Spits fire that is hot enough to melt boulders...   120    cel25c-4_A
# 14123                                               None  None  cel25c-15_A2
# 14124                                               None    80  cel25c-15_A4
# 14125                                               None  None   cel25c-73_A
# 14126                                               None    90   cel25c-88_A
# 14127                                               None    70  cel25c-15_A3
# 14128  Normally found only in the deep ocean, it has ...    70    cel25c-8_A
# 14129                                               None    50   cel25c-24_A
# 14130                                               None    30   cel25c-66_A
# 14131                                               None   100    cel25c-9_A
# 14132                                               None  None   cel25c-86_A
# 14133                                               None   150   cel25c-93_A
# 14134                                               None    70   cel25c-17_A
# 14135                                               None   110  cel25c-109_A
# 14136                                               None   170   cel25c-97_A
# 14137                                               None   170   cel25c-54_A
# 14138                                               None   130  cel25c-114_A
# 14139                                               None   220   cel25c-76_A
# 14140                                               None   170   cel25c-60_A
# 14141                                               None   120  cel25c-107_A
# 14142                                               None   130  cel25c-113_A
#
#        ...              rarity                              resistances  \
# 14118  ...  Classic Collection                                     None
# 14119  ...  Classic Collection                                     None
# 14120  ...  Classic Collection                                     None
# 14121  ...  Classic Collection                                     None
# 14122  ...  Classic Collection   [{'type': 'Fighting', 'value': '-30'}]
# 14123  ...  Classic Collection                                     None
# 14124  ...  Classic Collection                                     None
# 14125  ...  Classic Collection                                     None
# 14126  ...  Classic Collection                                     None
# 14127  ...  Classic Collection   [{'type': 'Fighting', 'value': '-30'}]
# 14128  ...  Classic Collection   [{'type': 'Fighting', 'value': '-30'}]
# 14129  ...  Classic Collection                                     None
# 14130  ...  Classic Collection                                     None
# 14131  ...  Classic Collection                                     None
# 14132  ...  Classic Collection                                     None
# 14133  ...  Classic Collection                                     None
# 14134  ...  Classic Collection    [{'type': 'Psychic', 'value': '-30'}]
# 14135  ...  Classic Collection      [{'type': 'Metal', 'value': '-20'}]
# 14136  ...  Classic Collection   [{'type': 'Darkness', 'value': '-20'}]
# 14137  ...  Classic Collection                                     None
# 14138  ...  Classic Collection                                     None
# 14139  ...  Classic Collection   [{'type': 'Fighting', 'value': '-20'}]
# 14140  ...  Classic Collection                                     None
# 14141  ...  Classic Collection  [{'type': 'Lightning', 'value': '-20'}]
# 14142  ...  Classic Collection                                     None
#
#                                         retreatCost  \
# 14118                                          None
# 14119             [Colorless, Colorless, Colorless]
# 14120                                          None
# 14121                        [Colorless, Colorless]
# 14122             [Colorless, Colorless, Colorless]
# 14123                                          None
# 14124                        [Colorless, Colorless]
# 14125                                          None
# 14126                                   [Colorless]
# 14127                        [Colorless, Colorless]
# 14128                        [Colorless, Colorless]
# 14129                                   [Colorless]
# 14130                                   [Colorless]
# 14131             [Colorless, Colorless, Colorless]
# 14132                                          None
# 14133                        [Colorless, Colorless]
# 14134                                   [Colorless]
# 14135                                          None
# 14136                        [Colorless, Colorless]
# 14137                        [Colorless, Colorless]
# 14138                        [Colorless, Colorless]
# 14139                                   [Colorless]
# 14140                                   [Colorless]
# 14141  [Colorless, Colorless, Colorless, Colorless]
# 14142                        [Colorless, Colorless]
#
#                                                    rules  \
# 14118                                               None
# 14119                                               None
# 14120  [Put this card onto your Active Garchomp [C]. ...
# 14121                                               None
# 14122                                               None
# 14123  [Each player plays with his or her Prize cards...
# 14124                                               None
# 14125  [Your opponent shuffles his or her hand into h...
# 14126  [When a Pokémon-ex has been knocked out, your ...
# 14127                                               None
# 14128                                               None
# 14129                                               None
# 14130                                               None
# 14131                                               None
# 14132  [You can play only one Supporter card each tur...
# 14133  [When a Pokémon-ex has been knocked out, your ...
# 14134  [You can't have more than 1 Pokémon★ in your d...
# 14135  [Put this card onto your Active Luxray [GL]. L...
# 14136  [When a Pokémon-EX has been Knocked Out, your ...
# 14137  [When a Pokémon-EX has been Knocked Out, your ...
# 14138                                               None
# 14139  [When a Pokémon-EX has been Knocked Out, your ...
# 14140  [When your Pokémon-GX is Knocked Out, your opp...
# 14141                                               None
# 14142                                               None
#
#                                                      set          subtypes  \
# 14118  {'id': 'cel25c', 'images': {'symbol': 'https:/...            [Baby]
# 14119  {'id': 'cel25c', 'images': {'symbol': 'https:/...         [Stage 2]
# 14120  {'id': 'cel25c', 'images': {'symbol': 'https:/...    [Level-Up, SP]
# 14121  {'id': 'cel25c', 'images': {'symbol': 'https:/...         [Stage 2]
# 14122  {'id': 'cel25c', 'images': {'symbol': 'https:/...         [Stage 2]
# 14123  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Supporter]
# 14124  {'id': 'cel25c', 'images': {'symbol': 'https:/...         [Stage 1]
# 14125  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Supporter]
# 14126  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Basic, EX]
# 14127  {'id': 'cel25c', 'images': {'symbol': 'https:/...           [Basic]
# 14128  {'id': 'cel25c', 'images': {'symbol': 'https:/...         [Stage 1]
# 14129  {'id': 'cel25c', 'images': {'symbol': 'https:/...           [Basic]
# 14130  {'id': 'cel25c', 'images': {'symbol': 'https:/...           [Basic]
# 14131  {'id': 'cel25c', 'images': {'symbol': 'https:/...           [Basic]
# 14132  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Supporter]
# 14133  {'id': 'cel25c', 'images': {'symbol': 'https:/...     [Stage 2, EX]
# 14134  {'id': 'cel25c', 'images': {'symbol': 'https:/...     [Basic, Star]
# 14135  {'id': 'cel25c', 'images': {'symbol': 'https:/...    [Level-Up, SP]
# 14136  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Basic, EX]
# 14137  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Basic, EX]
# 14138  {'id': 'cel25c', 'images': {'symbol': 'https:/...           [Basic]
# 14139  {'id': 'cel25c', 'images': {'symbol': 'https:/...        [MEGA, EX]
# 14140  {'id': 'cel25c', 'images': {'symbol': 'https:/...       [Basic, GX]
# 14141  {'id': 'cel25c', 'images': {'symbol': 'https:/...  [Stage 1, Prime]
# 14142  {'id': 'cel25c', 'images': {'symbol': 'https:/...           [Basic]
#
#       supertype                                          tcgplayer  \
# 14118   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14119   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14120   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14121   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14122   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14123   Trainer  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14124   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14125   Trainer  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14126   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14127   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14128   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14129   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14130   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14131   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14132   Trainer  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14133   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14134   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14135   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14136   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14137   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14138   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14139   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14140   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14141   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
# 14142   Pokémon  {'url': 'https://prices.pokemontcg.io/tcgplaye...
#
#                       types                              weaknesses
# 14118           [Colorless]                                    None
# 14119               [Water]  [{'type': 'Lightning', 'value': '×2'}]
# 14120           [Colorless]  [{'type': 'Colorless', 'value': '×2'}]
# 14121               [Grass]       [{'type': 'Fire', 'value': '×2'}]
# 14122                [Fire]      [{'type': 'Water', 'value': '×2'}]
# 14123                  None                                    None
# 14124            [Fighting]     [{'type': 'Grass', 'value': '+20'}]
# 14125                  None                                    None
# 14126             [Psychic]    [{'type': 'Psychic', 'value': '×2'}]
# 14127           [Lightning]                                    None
# 14128               [Water]      [{'type': 'Grass', 'value': '×2'}]
# 14129           [Lightning]   [{'type': 'Fighting', 'value': '×2'}]
# 14130               [Water]  [{'type': 'Lightning', 'value': '×2'}]
# 14131  [Fighting, Darkness]      [{'type': 'Grass', 'value': '×2'}]
# 14132                  None                                    None
# 14133                [Fire]    [{'type': 'Psychic', 'value': '×2'}]
# 14134            [Darkness]   [{'type': 'Fighting', 'value': '×2'}]
# 14135           [Lightning]   [{'type': 'Fighting', 'value': '×2'}]
# 14136               [Fairy]      [{'type': 'Metal', 'value': '×2'}]
# 14137             [Psychic]    [{'type': 'Psychic', 'value': '×2'}]
# 14138           [Lightning]   [{'type': 'Fighting', 'value': '×2'}]
# 14139           [Colorless]  [{'type': 'Lightning', 'value': '×2'}]
# 14140             [Psychic]                                    None
# 14141            [Fighting]      [{'type': 'Water', 'value': '×2'}]
# 14142                [Fire]      [{'type': 'Water', 'value': '×2'}]
#
# [25 rows x 26 columns]

# %%
data_frame_cards["id"].str.count("-").value_counts()
# Out:
# 1    15845
# Name: id, dtype: int64

# %%
data_frame_cards["id"].str.count("_").value_counts()
# Out:
# 0    15820
# 1       25
# Name: id, dtype: int64
